# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwitharavula/Competitive-programming_B20/blob/main/week2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fib(n, dp):
    if n == 0:
        return 0
    if n == 1:
        return 1
    if dp[n] != -1:
        return dp[n]
    dp[n] = fib(n - 1, dp) + fib(n - 2, dp)
    return dp[n]
n = int(input())
dp = [-1] * (n + 1)
print(fib(n, dp))
# Out:
# 10
# 55

# %%
n = int(input())
W = int(input())
values = []
weights = []
for i in range(n):
    v = int(input())
    w = int(input())
    values.append(v)
    weights.append(w)
dp = [[0 for _ in range(W + 1)] for _ in range(n + 1)]
for i in range(1, n + 1):
    for w in range(W + 1):
        if weights[i - 1] <= w:
            dp[i][w] = max(
                dp[i - 1][w],
                values[i - 1] + dp[i - 1][w - weights[i - 1]]
            )
        else:
            dp[i][w] = dp[i - 1][w]

print(dp[n][W])
# Out:
# 3
# 50
# 60
# 10
# 100
# 20
# 120
# 30
# 220

# %%
s1 = input().strip()
s2 = input().strip()
n = len(s1)
m = len(s2)
dp = [[0 for _ in range(m + 1)] for _ in range(n + 1)]
for i in range(1, n + 1):
    for j in range(1, m + 1):
        if s1[i - 1] == s2[j - 1]:
            dp[i][j] = 1 + dp[i - 1][j - 1]
        else:
            dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

print(dp[n][m])
# Out:
# AGGTAB
# GXTXAYB
# 4

# %%
n = int(input())
coins = []
for i in range(n):
    coins.append(int(input()))
amount = int(input())
dp = [10**9] * (amount + 1)
dp[0] = 0
for i in range(1, amount + 1):
    for coin in coins:
        if coin <= i:
            dp[i] = min(dp[i], dp[i - coin] + 1)
print(dp[amount])
# Out:
# 3
# 1
# 3
# 4
# 6
# 2

# %%
n = int(input())
p = []
for i in range(n):
    p.append(int(input()))
dp = [[0 for _ in range(n)] for _ in range(n)]
for length in range(2, n):
    for i in range(1, n - length + 1):
        j = i + length - 1
        dp[i][j] = 10**9
        for k in range(i, j):
            cost = dp[i][k] + dp[k + 1][j] + p[i - 1] * p[k] * p[j]
            if cost < dp[i][j]:
                dp[i][j] = cost
print(dp[1][n - 1])
# Out:
# 4
# 10
# 20
# 30
# 40
# 18000
